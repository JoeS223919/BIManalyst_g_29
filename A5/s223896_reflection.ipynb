# %% [markdown]
# # A5: Reflect

# %% [markdown]
# ## Your learning experience for the concept you focused on.
# __Identify your own level at the beginning of this course and where you ended:__
#
# - At the beginning of the course I had knowledge of ehat IFC was and in what context it was used, but i hasd no hands-on experience on working with IFCopenshell or anything related. I would therefore caracterize my starting point as modeller
#
# __What else do you still need to learn?__
#
# - I still need to learn a lot more about the structure of IFC files to be able to easier locate datapoint that i am analyzing. Also, better programming skills in Pytho would be nice
#
# __How you might use OpenBIM in the future?__
#
# - I am pursuing a specialization in sustainability and LCA, so it would be really cool to be able to make a tool that could be a full LCA based on an ifc file from ex. Revit.

# %% [markdown]
# ## Your process of developing the tutorial
# __Did the process of the course enable you to answer or define questions that you might need later for thesis?__
# - Yes! I have only gotten more interested in the data, programming, tech part of Sustainable engineering. Could be a job option og thesis topic to look into.
#
# __Would you have preferred to have been given less choice in the use cases?__
# - No. I liked that we should iterate on what to investigate and what problem should solve. It is more like real life where tasks rarely are completely defined
#
# __Was the number of tools for the course ok - should we have more or less? - if so which ones would you leave out?__
# - I think the number of big groups (STR, SPACE etc.) was OK, but I think it should be possible to work alone as analyst under these big groups, as some might have ideas that no one else want to participate in. That shouldn't hold them back.

# %% [markdown]
# ## (As a group) summary of the feedback you received on your tutorial
# - did the tool address the use case you identified?
# - What stage does the tool you created work in Advanced Building Design? ( Stage A, B, C and/ or D).

# %% [markdown]
# ## (Individual) Your future for Advanced use of OpenBIM
# __Are you likely to use OpenBIM tools in your thesis?__
# - If it is the case, I would probably work on developing a tool myself.
#
# __Are you likely to use OpenBIM tools in your professsional life in the next 10 years?__
# - Yes! I like the collaboration between the engineering stuff and the programming/developing.

# %% [markdown]
# ## (Individual) Wrap up
#
# __conclude the journey through A1-A5__
# - It has especially been interesting to learn how much information you can pull from the IFC files. You are not limited to anything and that incites creativity I think.
