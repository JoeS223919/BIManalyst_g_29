# %% [markdown]
# # Group 29 reflection
#
# **Process of developing the tutorial**
#
# The process of the course gave more curiosity and reflection of whether our master's thesis should include an openBIM tool. The amount of tools developed during the course has been at a good level. We liked how the class was divided into different groups where you could focus on an area that you are interested in. We also liked the freedom to develop a tool of any kind within the boundary given in the big groups.
#
# **Summary of the feedback you received on your tutorial**

# %% [markdown]
# ## Mathias (s223913) individual reflection
#
# **Learning experience**
#
# I have worked with IFC and openBIM to a certain exctend before, but in this course i have developed form a modeller to a selflearner in the field. I still need to learn more about connecting the different systems, and use the ifc-file for multiple analysis. I the future this will be important when improving af further develop the building industry, to tackle furure problems.
#
# **My future for Advanced use of OpenBIM**
#
# I am very likely to use OpenBIM tools again, since I am more confortable in it now. Furthermore the building industry needs to evolve and incooperate more of the building fields at the same time, in several stages of the project process. I will therefore need to use OpenBim in my professional life as well.
#
# **Wrap up**
#
# Other than teaching me about the benefits of OpenBIM, the course also made me a better user of python, which I will be using more in the future. By working in a step by step method (A1-A5), I could always see the next goal/assignment of the course, which helped a lot in the learning process. By working in a smaller group using a repository I learned how to be flexible, and that you sometimes need to go back to start, to fix and improve scripts that were developed later on. We had a constant sparring in our gruop which made it easy to keep eyes on the main goal. I am happy with our product even though it can be optimzed further.

# %% [markdown]
# ## Bastian (s223896) individual reflection
#
# __Your learning experience for the concept you focused on.__
#
# At the beginning of the course I had knowledge of ehat IFC was and in what context it was used, but i hasd no hands-on experience on working with IFCopenshell or anything related. I would therefore caracterize my starting point as modeller. I still need to learn a lot more about the structure of IFC files to be able to easier locate datapoint that i am analyzing. Also, better programming skills in Python would be nice. I am pursuing a specialization in sustainability and LCA, so it would be really cool to be able to make a tool that could be a full LCA based on an ifc file from ex. Revit.
#
#
# __Your future for Advanced use of OpenBIM__
#
# I could definitely use OpenBIM for my coming thesis but also in my professional career going forward. I think i will only become more relevant in the future.
#
# __Wrap up__
#
# It has especially been interesting to learn how much information you can pull from the IFC files. You are not limited to anything and that incites creativity I think.

# %% [markdown]
# ## Johannes (s223919) individual reflection
#
#
# **Learning experience**
#
# At the start of the course i understood the concept of openBIM at what its purpose was. During the course of this project i learned more about what openBIM is able to do. I can see how it can be very useful to be able to write programs that can analyse the data of BIM models. Using other programs such as Revit, there arent the same oportunities to go into the code of the program and or the model to be able to analyse or modify it.
#
#
# **My future for Advanced use of OpenBIM**
#
# I think that i might use OpenBIM. I already used and mentioned BonsaiBIM in my Bachelors thesis.
# Its hard to say if i would use OpenBIM in 10 years time, i would definately be open to it. I do however, think that it needs some work. BonsaiBIM and its reliance on Blender isnt the best solution. It also depends on the company, and their work flow. But if the process of creating models, the tools and so on, get better, then absolutely.
#
# **Wrap up**
# We started out not really knowing what the program should be able to do. It really started out as one thing and ended up more as another thing. But going through the assignments, and writing the codes and scripts then it became clearer what we were capable of doing. I do think we ended up with a useful tool, thats capable of doing good things, that could be useful, in a real world situation
